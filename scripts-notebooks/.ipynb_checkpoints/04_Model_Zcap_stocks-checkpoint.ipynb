# %%
library(tidyverse)
`%nin%` <- Negate(`%in%`)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
Krause_stocks <- read.csv("../data/stocks.csv" , fileEncoding="latin1") |>
                 dplyr::rename(Article.ID = `ï..Article.ID`)
Krause_stocks_cols <- dput(colnames(Krause_stocks))
# Out:
# c("Article.ID", "Publication.year", "Study.site", "Country",
# "Latitude", "Longitude", "Coastal.typology", "Marine.ecoregion",
# "Seagrass.bioregion", "Seagrass.functionalmorphological.group",
# "Seagrass.species", "Seagrass.genus", "Additional.identification",
# "Above.ground.biomass", "Below.ground.biomass", "Total.biomass",
# "Sampling.depth", "Ctot.stock", "Ctot.content", "Corg.stock",
# "Corg.content", "Cinorg.stock", "Cinorg.content", "Ctot.stock.15cm",
# "Corg.stock.15cm", "Cinorg.stock.15cm", "Ctot.stock.30cm", "Corg.stock.30cm",
# "Cinorg.stock.30cm", "Ctot.stock.50cm", "Corg.stock.50cm", "Cinorg.stock.50cm",
# "Ctot.stock.100cm", "Corg.stock.100cm", "Cinorg.stock.100cm",
# "OM.content", "Porosity", "Dry.Bulk.Density", "Grain.size", "Fraction.mud",
# "Notes")

# %%
Krause_data <- read.csv("../data/Core_data.csv" , fileEncoding="latin1")
Krause_data_cols <- dput(colnames(Krause_data))
# Out:
# c("ï..Article.ID", "Primary.reference", "Secondary.reference",
# "Publication.year", "Site.name", "Country", "Latitude", "Longitude",
# "Species", "Core.ID", "Top.of.section", "Bottom.of.section",
# "Depth.at.center.of.slice", "Thickness.sediment.slice", "Dry.Bulk.Density",
# "OM.content", "OM.density", "Corg", "Cinorg", "Cinorg.stock.increment",
# "Corg.stock.increment", "Ctot.stock.increment", "DBD.core", "OM.content.core",
# "Corg.core", "Cinorg.core", "Cinorg.stock.core", "Corg.stock.core",
# "Ctot.stock.core", "Depth.of.core", "X", "X.1", "X.2")

# %%
Krause_database <- read_rds("../data/Krause_database.rds") |>
                   dplyr::mutate(data_source = "Krause_et_al_2025") |>
                   dplyr::relocate(data_source)
dim(Krause_database)
# Out:
# [1] 2813   48

# %%
Krause_database |> select(where(~ !all(is.na(.)))) |> dim()
# Out:
# [1] 2813   48

# %%
zaf_data_df <- read_rds("../data/zaf_data_df.rds") |>
               dplyr::filter(!is.na(fraction_organic_matter)) |>
               dplyr::filter(site_id %nin% c("Kariega","Keurbooms")) 

glimpse(zaf_data_df)
# Out:
# Rows: 548
# Columns: 13
# $ data_source             <chr> "Bossert_et_al_2024", "Bossert_et_al_2024", "B…
# $ study_id                <chr> "Bossert_et_al_2024", "Bossert_et_al_2024", "B…
# $ site_id                 <chr> "Berg", "Berg", "Berg", "Berg", "Berg", "Berg"…
# $ core_id                 <chr> "LWR_SS1_R1", "LWR_SS1_R1", "LWR_SS1_R1", "LWR…
# $ depth_min               <dbl> 0, 3, 6, 10, 0, 3, 6, 10, 0, 3, 6, 10, 0, 3, 6…
# $ depth_max               <dbl> 3, 6, 10, 15, 3, 6, 10, 15, 3, 6, 10, 15, 3, 6…
# $ dry_bulk_density        <dbl> 1.0301527, 1.0991792, 0.8814128, 1.1093583, 0.…
# $ fraction_organic_matter <dbl> 0.40, 0.25, 0.97, 0.45, 0.34, 0.69, 0.30, 0.34…
# $ year                    <dbl> 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022…
# $ latitude                <dbl> -32.7716, -32.7716, -32.7716, -32.7716, -32.77…
# $ longitude               <dbl> 18.14287, 18.14287, 18.14287, 18.14287, 18.142…
# $ species_code            <chr> "Zostera capensis", "Zostera capensis", "Zoste…
# $ code_type               <chr> "Genus species", "Genus species", "Genus speci…

# %%
dim(zaf_data_df)
# Out:
# [1] 548  13

# %%
(zaf_data_noDBD <- zaf_data_df |>
                   dplyr::filter(is.na(dry_bulk_density))) |> dim()
# Out:
# [1] 142  13

# %%
zaf_data_noDBD |> dplyr::select(study_id, site_id, core_id, depth_min, depth_max, fraction_organic_matter, dry_bulk_density)
# Out:
#     study_id                site_id
# 1   Bekker_2015             Knysna
# 2   Bekker_2015             Knysna
# 3   Bekker_2015             Knysna
# 4   Bekker_2015             Knysna
# 5   Bezuidenhout_et_al_2011 Kromme
# 6   Bezuidenhout_et_al_2011 Kromme
# 7   Bezuidenhout_et_al_2011 Kromme
# 8   Bezuidenhout_et_al_2011 Kromme
# 9   Bezuidenhout_et_al_2011 Kromme
# 10  Bezuidenhout_et_al_2011 Kromme
# 11  Bezuidenhout_et_al_2011 Kromme
# 12  Bezuidenhout_et_al_2011 Kromme
# 13  Bezuidenhout_et_al_2011 Kromme
# 14  Bezuidenhout_et_al_2011 Kromme
# 15  Bezuidenhout_et_al_2011 Kromme
# 16  Bezuidenhout_et_al_2011 Kromme
# 17  Bezuidenhout_et_al_2011 Kromme
# 18  Bezuidenhout_et_al_2011 Kromme
# 19  Bezuidenhout_et_al_2011 Kromme
# 20  Bezuidenhout_et_al_2011 Kromme
# 21  Bezuidenhout_et_al_2011 Kromme
# 22  Bezuidenhout_et_al_2011 Kromme
# 23  Bezuidenhout_et_al_2011 Kromme
# 24  Brown_and_Rajkaran_2020 Kobonqaba
# 25  Brown_and_Rajkaran_2020 Kobonqaba
# 26  Brown_and_Rajkaran_2020 Kobonqaba
# 27  Brown_and_Rajkaran_2020 Kobonqaba
# 28  Brown_and_Rajkaran_2020 Kobonqaba
# 29  Brown_and_Rajkaran_2020 Kobonqaba
# 30  Brown_and_Rajkaran_2020 Kobonqaba
# ⋮   ⋮                       ⋮
# 113 Els_2019                Swartkops
# 114 Els_2019                Swartkops
# 115 Els_2019                Swartkops
# 116 Els_2019                Swartkops
# 117 Els_2019                Swartkops
# 118 Els_2019                Swartkops
# 119 Els_2019                Swartkops
# 120 Els_2019                Swartkops
# 121 Rajkaran_and_Adams_2011 Mngazana
# 122 Rajkaran_and_Adams_2011 Mngazana
# 123 Rajkaran_and_Adams_2011 Mngazana
# 124 Rajkaran_and_Adams_2011 Mngazana
# 125 Rajkaran_and_Adams_2011 Mngazana
# 126 Rajkaran_and_Adams_2011 Mngazana
# 127 Rajkaran_and_Adams_2011 Mngazana
# 128 Rajkaran_and_Adams_2011 Mngazana
# 129 Rajkaran_and_Adams_2011 Mngazana
# 130 Rajkaran_and_Adams_2011 Mngazana
# 131 Rajkaran_and_Adams_2011 Mngazana
# 132 Rajkaran_and_Adams_2011 Mngazana
# 133 Rajkaran_and_Adams_2011 Mngazana
# 134 Veldkornet_2016_PhD     Knysna
# 135 Veldkornet_2016_PhD     Knysna
# 136 Veldkornet_2016_PhD     Kromme
# 137 Veldkornet_2016_PhD     Kromme
# 138 Veldkornet_2016_PhD     Swartkops
# 139 Veldkornet_2016_PhD     Swartkops
# 140 Veldkornet_2016_PhD     Swartkops
# 141 Veldkornet_2016_PhD     Swartkops
# 142 Veldkornet_2016_PhD     Swartkops
#     core_id                                                 depth_min depth_max
# 1   Knysna-Zostera capensis-Submerged-surface sample-1        0         5
# 2   Knysna-Zostera capensis-Submerged-surface sample-2        0         5
# 3   Knysna-Zostera capensis-Submerged-surface sample-3        0         5
# 4   Knysna-Zostera capensis-Submerged-surface sample-4        0         5
# 5   Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 1   5        15
# 6   Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 1   0         5
# 7   Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 1 100       120
# 8   Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 1   5        15
# 9   Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 1   0         5
# 10  Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 1 100       120
# 11  Kromme-Zostera capensis-Winter-Transect 1 Zone a-core 1   5        15
# 12  Kromme-Zostera capensis-Winter-Transect 1 Zone a-core 1   0         5
# 13  Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 1   5        15
# 14  Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 1   0         5
# 15  Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 1 100       120
# 16  Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 2   5        15
# 17  Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 2   0         5
# 18  Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 2 100       120
# 19  Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 2   5        15
# 20  Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 2   0         5
# 21  Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 2 100       120
# 22  Kromme-Zostera capensis-Winter-Transect 1 Zone a-core 2   0         5
# 23  Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 2   0         5
# 24  Kobonqaba-Zostera capensis-core 1                         0         3
# 25  Kobonqaba-Zostera capensis-core 1                        12        15
# 26  Kobonqaba-Zostera capensis-core 1                        15        18
# 27  Kobonqaba-Zostera capensis-core 1                        18        21
# 28  Kobonqaba-Zostera capensis-core 1                         3         6
# 29  Kobonqaba-Zostera capensis-core 1                         6         9
# 30  Kobonqaba-Zostera capensis-core 1                         9        12
# ⋮   ⋮                                                       ⋮         ⋮
# 113 Swartkops-5-Winter-core-3                                0         10
# 114 Swartkops-5-Winter-core-3                               10         25
# 115 Swartkops-5-Winter-core-3                               25         50
# 116 Swartkops-5-Winter-core-3                               50        100
# 117 Swartkops-6-Winter-core-2                                0         10
# 118 Swartkops-6-Winter-core-2                               10         25
# 119 Swartkops-6-Winter-core-2                               25         50
# 120 Swartkops-6-Winter-core-2                               50        100
# 121 Mngazana-core-1                                          0          3
# 122 Mngazana-core-1                                         12         15
# 123 Mngazana-core-1                                         15         18
# 124 Mngazana-core-1                                         18         21
# 125 Mngazana-core-1                                         21         24
# 126 Mngazana-core-1                                         24         27
# 127 Mngazana-core-1                                         27         30
# 128 Mngazana-core-1                                         30         33
# 129 Mngazana-core-1                                         33         36
# 130 Mngazana-core-1                                          3          6
# 131 Mngazana-core-1                                         36         39
# 132 Mngazana-core-1                                          6          9
# 133 Mngazana-core-1                                          9         12
# 134 Knysna-surface sample 42                                 0          5
# 135 Knysna-surface sample 43                                 0          5
# 136 Kromme-surface sample 15                                 0          5
# 137 Kromme-surface sample 16                                 0          5
# 138 Swartkops-surface sample 7                               0          5
# 139 Swartkops-surface sample 8                               0          5
# 140 Swartkops-surface sample 9                               0          5
# 141 Swartkops-surface sample 10                              0          5
# 142 Swartkops-surface sample 11                              0          5
#     fraction_organic_matter dry_bulk_density
# 1    1.5735144              NA
# 2    2.0688444              NA
# 3    2.3656377              NA
# 4    2.4337427              NA
# 5    0.9248434              NA
# 6    2.9653294              NA
# 7    0.5283731              NA
# 8    1.5660455              NA
# 9    4.6012445              NA
# 10   0.7665744              NA
# 11   2.3808014              NA
# 12   2.7022676              NA
# 13   1.7358737              NA
# 14   5.0420965              NA
# 15   0.5900957              NA
# 16   8.5700000              NA
# 17  17.4600000              NA
# 18   7.8700000              NA
# 19  10.9700000              NA
# 20  24.1800000              NA
# 21  10.7200000              NA
# 22  18.0252249              NA
# 23  17.7925716              NA
# 24  18.1439042              NA
# 25  14.0615626              NA
# 26   9.2408004              NA
# 27  11.5159213              NA
# 28  16.1510720              NA
# 29  13.1782626              NA
# 30  17.9093668              NA
# ⋮   ⋮                       ⋮
# 113  2.730021               NA
# 114  2.725896               NA
# 115  3.243967               NA
# 116  2.769793               NA
# 117  2.897057               NA
# 118  3.112808               NA
# 119  2.947495               NA
# 120  2.997166               NA
# 121 23.252690               NA
# 122 18.694324               NA
# 123 16.877855               NA
# 124 13.818794               NA
# 125 12.383003               NA
# 126 14.139617               NA
# 127 18.334685               NA
# 128 18.795552               NA
# 129 24.548711               NA
# 130 24.259509               NA
# 131 45.435418               NA
# 132 23.054493               NA
# 133 22.433326               NA
# 134  1.400000               NA
# 135  1.700000               NA
# 136  2.000000               NA
# 137  2.800000               NA
# 138  1.600000               NA
# 139  1.900000               NA
# 140  1.900000               NA
# 141  1.900000               NA
# 142  3.300000               NA

# %%
no_DBD_cores <- unique(zaf_data_noDBD$core_id)

# %%
unique(zaf_data_df$data_source)
# Out:
# [1] "Bossert_et_al_2024" "Machite_et_al"      "Ndhlovu_et_al"

# %%
setdiff(names(zaf_data_df), names(Krause_stocks))
# Out:
#  [1] "data_source"             "study_id"
#  [3] "site_id"                 "core_id"
#  [5] "depth_min"               "depth_max"
#  [7] "dry_bulk_density"        "fraction_organic_matter"
#  [9] "year"                    "latitude"
# [11] "longitude"               "species_code"
# [13] "code_type"

# %%
(Zcapensis_depthseries <- dplyr::rename(rename(zaf_data_df, Article.ID = study_id),
                                               Study.site = site_id,
                                               Latitude = latitude,
                                               Longitude = longitude,
                                               Seagrass.species = species_code,
                                               Core.ID = core_id,
                                               Top.of.section = depth_min, 
                                               Bottom.of.section = depth_max,
                                               Dry.Bulk.Density = dry_bulk_density,
                                               Corg = fraction_organic_matter) |> 
                            dplyr::mutate(Publication.year = str_split_fixed(Article.ID, "_", 4)[, 4],
                                             Seagrass.genus = str_split_fixed(Seagrass.species, " ", 2)[,2],
                                             Country = "South Africa",
                                             Marine.ecoregion = "Temperate Southern Africa",
                                             Seagrass.bioregion = "Temperate Southern Oceans",
                                             Coastal.typology = "Type I: Small deltas",
                                             Seagrass.functionalmorphological.group = "Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)",
                                             Coastal.typology = if_else(Study.site == "Langebaan", "Type III: Lagoons", Coastal.typology),
                                             Thickness.sediment.slice = Bottom.of.section - Top.of.section,
                                             Depth.at.center.of.slice = Top.of.section + (Thickness.sediment.slice/2),
                                             depth_interval = Top.of.section + Thickness.sediment.slice) |>
                         dplyr::relocate(any_of(Krause_stocks_cols), .before = everything())) |>
                         dplyr::select(where(is.numeric)) |>
                         dplyr::sample_n(5)
# Out:
#   Latitude  Longitude Dry.Bulk.Density Top.of.section Bottom.of.section Corg
# 1  23.05105 -34.05871 1.3989000         5             10                0.241
# 2  22.99216 -34.03369 1.4506720        10             20                0.197
# 3 -32.81825  18.19599 1.0358695         6             10                0.440
# 4 -32.81825  18.19599 1.2302677         6             10                0.350
# 5 -32.77160  18.14287 0.9608375        10             15                8.230
#   year Thickness.sediment.slice Depth.at.center.of.slice depth_interval
# 1 2021  5                        7.5                     10
# 2 2021 10                       15.0                     20
# 3 2022  4                        8.0                     10
# 4 2022  4                        8.0                     10
# 5 2022  5                       12.5                     15

# %%
Zcapensis_depthseries |> 
select(any_of(c("Study.site", "Article.ID", "Publication.year", "Core.ID", "Dry.Bulk.Density", "Corg"))) |>
filter(Study.site == "Swartkops")
# Out:
#    Study.site Article.ID         Publication.year Core.ID
# 1  Swartkops  Els_2019                            Swartkops-1-Summer-core-3
# 2  Swartkops  Els_2019                            Swartkops-1-Summer-core-3
# 3  Swartkops  Els_2019                            Swartkops-1-Summer-core-3
# 4  Swartkops  Els_2019                            Swartkops-1-Summer-core-3
# 5  Swartkops  Els_2019                            Swartkops-2-Summer-core-3
# 6  Swartkops  Els_2019                            Swartkops-2-Summer-core-3
# 7  Swartkops  Els_2019                            Swartkops-2-Summer-core-3
# 8  Swartkops  Els_2019                            Swartkops-2-Summer-core-3
# 9  Swartkops  Els_2019                            Swartkops-3-Summer-core-3
# 10 Swartkops  Els_2019                            Swartkops-3-Summer-core-3
# 11 Swartkops  Els_2019                            Swartkops-3-Summer-core-3
# 12 Swartkops  Els_2019                            Swartkops-3-Summer-core-3
# 13 Swartkops  Els_2019                            Swartkops-4-Summer-core-3
# 14 Swartkops  Els_2019                            Swartkops-4-Summer-core-3
# 15 Swartkops  Els_2019                            Swartkops-4-Summer-core-3
# 16 Swartkops  Els_2019                            Swartkops-4-Summer-core-3
# 17 Swartkops  Els_2019                            Swartkops-5-Summer-core-3
# 18 Swartkops  Els_2019                            Swartkops-5-Summer-core-3
# 19 Swartkops  Els_2019                            Swartkops-5-Summer-core-3
# 20 Swartkops  Els_2019                            Swartkops-5-Summer-core-3
# 21 Swartkops  Els_2019                            Swartkops-6-Summer-core-1
# 22 Swartkops  Els_2019                            Swartkops-6-Summer-core-1
# 23 Swartkops  Els_2019                            Swartkops-6-Summer-core-1
# 24 Swartkops  Els_2019                            Swartkops-6-Summer-core-1
# 25 Swartkops  Els_2019                            Swartkops-1-Winter-core-3
# 26 Swartkops  Els_2019                            Swartkops-1-Winter-core-3
# 27 Swartkops  Els_2019                            Swartkops-1-Winter-core-3
# 28 Swartkops  Els_2019                            Swartkops-1-Winter-core-3
# 29 Swartkops  Els_2019                            Swartkops-2-Winter-core-3
# 30 Swartkops  Els_2019                            Swartkops-2-Winter-core-3
# ⋮  ⋮          ⋮                  ⋮                ⋮
# 64 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C3
# 65 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C4
# 66 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C1
# 67 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C2
# 68 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C3
# 69 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C4
# 70 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C1
# 71 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C2
# 72 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C3
# 73 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops1_C4
# 74 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C1
# 75 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C2
# 76 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C3
# 77 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C4
# 78 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C1
# 79 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C2
# 80 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C3
# 81 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C4
# 82 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C1
# 83 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C2
# 84 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C3
# 85 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C4
# 86 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C1
# 87 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C2
# 88 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C3
# 89 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C4
# 90 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C1
# 91 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C2
# 92 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C3
# 93 Swartkops  Ndhlovu_et_al_2024 2024             Swartkops2_C4
#    Dry.Bulk.Density Corg
# 1  NA               6.481311
# 2  NA               3.857229
# 3  NA               7.404405
# 4  NA               1.957059
# 5  NA               5.652479
# 6  NA               4.311114
# 7  NA               3.523443
# 8  NA               3.646372
# 9  NA               4.238085
# 10 NA               3.690215
# 11 NA               4.736618
# 12 NA               2.985934
# 13 NA               5.672044
# 14 NA               4.574672
# 15 NA               5.169270
# 16 NA               3.325747
# 17 NA               2.532569
# 18 NA               2.602745
# 19 NA               4.981796
# 20 NA               2.567922
# 21 NA               2.652957
# 22 NA               3.092360
# 23 NA               3.964150
# 24 NA               3.772546
# 25 NA               1.985291
# 26 NA               1.654780
# 27 NA               1.493437
# 28 NA               1.520496
# 29 NA               4.604211
# 30 NA               3.530680
# ⋮  ⋮                ⋮
# 64 1.45516          3.280
# 65 1.51242          2.603
# 66 1.10135          2.340
# 67 1.30985          2.569
# 68 1.02685          4.037
# 69 1.41350          3.046
# 70 1.55050          2.631
# 71 1.43630          2.590
# 72 1.36594          2.911
# 73 1.41480          2.867
# 74 1.24490          0.257
# 75 1.64215          0.040
# 76 1.51500          0.633
# 77 0.99450          0.170
# 78 1.32380          0.024
# 79 1.54964          0.189
# 80 1.53060          0.171
# 81 1.45752          0.099
# 82 1.40290          0.184
# 83 1.49962          0.275
# 84 1.49608          0.203
# 85 1.48846          0.215
# 86 1.02610          0.049
# 87 1.45655          0.018
# 88 1.50910          0.483
# 89 1.43490          0.083
# 90 1.50724          0.096
# 91 1.49542          0.086
# 92 1.50826          0.004
# 93 1.46486          0.075

# %%
 dput(colnames(Zcapensis_depthseries))
# Out:
# c("Article.ID", "Publication.year", "Study.site", "Country",
# "Latitude", "Longitude", "Coastal.typology", "Marine.ecoregion",
# "Seagrass.bioregion", "Seagrass.functionalmorphological.group",
# "Seagrass.species", "Seagrass.genus", "Dry.Bulk.Density", "data_source",
# "Core.ID", "Top.of.section", "Bottom.of.section", "Corg", "year",
# "code_type", "Thickness.sediment.slice", "Depth.at.center.of.slice",
# "depth_interval")

# %%
grouping_cols <- c("Article.ID", "Publication.year", "Study.site", "Country", 
                  "Latitude", "Longitude", "Coastal.typology", "Marine.ecoregion", 
                  "Seagrass.bioregion", "Seagrass.functionalmorphological.group", 
                  "Seagrass.species", "Seagrass.genus", "data_source", 
                  "Core.ID", "year", "code_type")

# %%
coredata_slices <-  dplyr::group_by(Zcapensis_depthseries, Study.site) |>
                    group_modify(~ {
                    .x$Dry.Bulk.Density <- impute_regression(.x, "Dry.Bulk.Density", "Depth.at.center.of.slice")
                    return(.x) }) |> 
                    dplyr::ungroup() |>
                    dplyr::mutate(Corg_DBD = Dry.Bulk.Density * (Corg/100), 
                                  Carbon_density = Corg_DBD * Thickness.sediment.slice,
                                  Corg_DBD = Dry.Bulk.Density * (Corg/100), Corg_DBD_interval = Corg_DBD * Thickness.sediment.slice) |>
                    dplyr::group_by(across(all_of(grouping_cols))) |>
                    dplyr::mutate(cumsum_Corg_DBD = cumsum(Corg_DBD_interval),
                                  carbon_stock_MgC_ha = cumsum_Corg_DBD * (1/1000000) * (100000000/1)) |>
                        dplyr::ungroup()

# %%
dput(colnames(coredata_slices))
# Out:
# c("Study.site", "Article.ID", "Publication.year", "Country",
# "Latitude", "Longitude", "Coastal.typology", "Marine.ecoregion",
# "Seagrass.bioregion", "Seagrass.functionalmorphological.group",
# "Seagrass.species", "Seagrass.genus", "Dry.Bulk.Density", "data_source",
# "Core.ID", "Top.of.section", "Bottom.of.section", "Corg", "year",
# "code_type", "Thickness.sediment.slice", "Depth.at.center.of.slice",
# "depth_interval", "Corg_DBD", "Carbon_density", "Corg_DBD_interval",
# "cumsum_Corg_DBD", "carbon_stock_MgC_ha")

# %%
dim(coredata_slices)
coredata_slices_noDBD <- coredata_slices |> dplyr::filter(is.na(Dry.Bulk.Density))
dim(coredata_slices_noDBD)
coredata_slices_DBD <- coredata_slices |> dplyr::filter(!is.na(Dry.Bulk.Density))
dim(coredata_slices_DBD)
# Out:
# [1] 548  28
# [1] 28 28
# [1] 520  28

# %%
fit_DBD <- lm(Dry.Bulk.Density ~ Depth.at.center.of.slice, data = Zcapensis_depthseries)
predicted_DBD <- predict(fit_DBD, newdata = Zcapensis_depthseries)
Zcapensis_depthseries$Dry.Bulk.Density[is.na(Zcapensis_depthseries$Dry.Bulk.Density)] <- predicted_DBD[is.na(Zcapensis_depthseries$Dry.Bulk.Density)]
coredata_slices_fill_DBD <- dplyr::filter(Zcapensis_depthseries, Core.ID %in% coredata_slices_noDBD$Core.ID) |>
                            dplyr::mutate(Corg_DBD = Dry.Bulk.Density * (Corg/100), 
                                          Carbon_density = Corg_DBD * Thickness.sediment.slice,
                                          Corg_DBD = Dry.Bulk.Density * (Corg/100), Corg_DBD_interval = Corg_DBD * Thickness.sediment.slice) |>
                                          dplyr::group_by(across(all_of(grouping_cols))) |>
                                          dplyr::mutate(cumsum_Corg_DBD = cumsum(Corg_DBD_interval),
                                                        carbon_stock_MgC_ha = cumsum_Corg_DBD * (1/1000000) * (100000000/1)) |>
                                            dplyr::ungroup() 

dim(coredata_slices_fill_DBD)
(coredata_slicex <- rbind(coredata_slices_DBD, coredata_slices_fill_DBD)) |> dim()
Zcapensis_depthseries$Core.ID[Zcapensis_depthseries$Core.ID %nin% coredata_slicex$Core.ID]
# Out:
# [1] 28 28
# [1] 548  28
# character(0)

# %%
coredata_slices_fill_DBD |>
select(Dry.Bulk.Density) |>
filter(is.na(Dry.Bulk.Density))
# Out:
#      Dry.Bulk.Density

# %%
coredata_slicex |>  
dplyr::select(c(Article.ID, Publication.year, Study.site, Core.ID, Dry.Bulk.Density)) |>
dplyr::filter(Core.ID %in% zaf_data_noDBD$core_id)
# Out:
#     Article.ID              Publication.year Study.site
# 1   Bekker_2015                              Knysna
# 2   Bekker_2015                              Knysna
# 3   Bekker_2015                              Knysna
# 4   Bekker_2015                              Knysna
# 5   Els_2017                                 Knysna
# 6   Els_2017                                 Knysna
# 7   Els_2017                                 Knysna
# 8   Els_2017                                 Knysna
# 9   Els_2017                                 Knysna
# 10  Els_2017                                 Knysna
# 11  Els_2017                                 Knysna
# 12  Els_2017                                 Knysna
# 13  Els_2017                                 Knysna
# 14  Els_2017                                 Knysna
# 15  Els_2017                                 Knysna
# 16  Els_2017                                 Knysna
# 17  Els_2017                                 Knysna
# 18  Els_2017                                 Knysna
# 19  Els_2017                                 Knysna
# 20  Els_2017                                 Knysna
# 21  Els_2017                                 Knysna
# 22  Els_2017                                 Knysna
# 23  Els_2017                                 Knysna
# 24  Els_2017                                 Knysna
# 25  Els_2017                                 Knysna
# 26  Els_2017                                 Knysna
# 27  Els_2017                                 Knysna
# 28  Els_2017                                 Knysna
# 29  Els_2017                                 Knysna
# 30  Els_2017                                 Knysna
# ⋮   ⋮                       ⋮                ⋮
# 113 Veldkornet_2016_PhD                      Swartkops
# 114 Veldkornet_2016_PhD                      Swartkops
# 115 Bezuidenhout_et_al_2011 2011             Kromme
# 116 Bezuidenhout_et_al_2011 2011             Kromme
# 117 Bezuidenhout_et_al_2011 2011             Kromme
# 118 Bezuidenhout_et_al_2011 2011             Kromme
# 119 Bezuidenhout_et_al_2011 2011             Kromme
# 120 Bezuidenhout_et_al_2011 2011             Kromme
# 121 Bezuidenhout_et_al_2011 2011             Kromme
# 122 Bezuidenhout_et_al_2011 2011             Kromme
# 123 Bezuidenhout_et_al_2011 2011             Kromme
# 124 Bezuidenhout_et_al_2011 2011             Kromme
# 125 Bezuidenhout_et_al_2011 2011             Kromme
# 126 Bezuidenhout_et_al_2011 2011             Kromme
# 127 Bezuidenhout_et_al_2011 2011             Kromme
# 128 Bezuidenhout_et_al_2011 2011             Kromme
# 129 Bezuidenhout_et_al_2011 2011             Kromme
# 130 Bezuidenhout_et_al_2011 2011             Kromme
# 131 Bezuidenhout_et_al_2011 2011             Kromme
# 132 Bezuidenhout_et_al_2011 2011             Kromme
# 133 Bezuidenhout_et_al_2011 2011             Kromme
# 134 Brown_and_Rajkaran_2020 2020             Kobonqaba
# 135 Brown_and_Rajkaran_2020 2020             Kobonqaba
# 136 Brown_and_Rajkaran_2020 2020             Kobonqaba
# 137 Brown_and_Rajkaran_2020 2020             Kobonqaba
# 138 Brown_and_Rajkaran_2020 2020             Kobonqaba
# 139 Brown_and_Rajkaran_2020 2020             Kobonqaba
# 140 Brown_and_Rajkaran_2020 2020             Kobonqaba
# 141 Veldkornet_2016_PhD                      Kromme
# 142 Veldkornet_2016_PhD                      Kromme
#     Core.ID                                                 Dry.Bulk.Density
# 1   Knysna-Zostera capensis-Submerged-surface sample-1      1.381007
# 2   Knysna-Zostera capensis-Submerged-surface sample-2      1.381007
# 3   Knysna-Zostera capensis-Submerged-surface sample-3      1.381007
# 4   Knysna-Zostera capensis-Submerged-surface sample-4      1.381007
# 5   Knysna-Ashmead-core-1                                   1.386373
# 6   Knysna-Ashmead-core-1                                   1.408907
# 7   Knysna-Ashmead-core-1                                   1.425002
# 8   Knysna-Ashmead-core-1                                   1.440025
# 9   Knysna-Ashmead-core-1                                   1.458267
# 10  Knysna-Ashmead-core-1                                   1.473290
# 11  Knysna-Ashmead-core-1                                   1.489386
# 12  Knysna-Lower-core-1                                     1.386373
# 13  Knysna-Lower-core-1                                     1.408907
# 14  Knysna-Lower-core-1                                     1.425002
# 15  Knysna-Lower-core-1                                     1.440025
# 16  Knysna-Lower-core-1                                     1.458267
# 17  Knysna-Lower-core-1                                     1.473290
# 18  Knysna-Lower-core-1                                     1.489386
# 19  Knysna-Middle-core-1                                    1.386373
# 20  Knysna-Middle-core-1                                    1.408907
# 21  Knysna-Middle-core-1                                    1.425002
# 22  Knysna-Middle-core-1                                    1.440025
# 23  Knysna-Middle-core-1                                    1.458267
# 24  Knysna-Middle-core-1                                    1.473290
# 25  Knysna-Middle-core-1                                    1.481874
# 26  Knysna-Middle-core-1                                    1.489386
# 27  Knysna-Middle-core-1                                    1.503335
# 28  Knysna-Middle-core-1                                    1.518358
# 29  Knysna-Middle-core-1                                    1.536600
# 30  Knysna-Middle-core-1                                    1.558061
# ⋮   ⋮                                                       ⋮
# 113 Swartkops-surface sample 10                             1.288427
# 114 Swartkops-surface sample 11                             1.288427
# 115 Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 1 1.213289
# 116 Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 1 1.159965
# 117 Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 1 1.924275
# 118 Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 1 1.213289
# 119 Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 1 1.159965
# 120 Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 1 1.924275
# 121 Kromme-Zostera capensis-Winter-Transect 1 Zone a-core 1 1.213289
# 122 Kromme-Zostera capensis-Winter-Transect 1 Zone a-core 1 1.159965
# 123 Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 1 1.213289
# 124 Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 1 1.159965
# 125 Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 1 1.924275
# 126 Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 2 1.213289
# 127 Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 2 1.159965
# 128 Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 2 1.924275
# 129 Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 2 1.213289
# 130 Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 2 1.159965
# 131 Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 2 1.924275
# 132 Kromme-Zostera capensis-Winter-Transect 1 Zone a-core 2 1.159965
# 133 Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 2 1.159965
# 134 Kobonqaba-Zostera capensis-core 1                       1.152855
# 135 Kobonqaba-Zostera capensis-core 1                       1.238173
# 136 Kobonqaba-Zostera capensis-core 1                       1.259503
# 137 Kobonqaba-Zostera capensis-core 1                       1.280832
# 138 Kobonqaba-Zostera capensis-core 1                       1.174184
# 139 Kobonqaba-Zostera capensis-core 1                       1.195514
# 140 Kobonqaba-Zostera capensis-core 1                       1.216844
# 141 Kromme-surface sample 15                                1.159965
# 142 Kromme-surface sample 16                                1.159965

# %%
dim(coredata_slices)
inspectdf::inspect_cat(coredata_slicex) |> inspectdf::show_plot()
# Out:
# [1] 548  28
# plot without title

# %%
glimpse(coredata_slicex)
# Out:
# Rows: 548
# Columns: 28
# $ Study.site                             <chr> "Berg", "Berg", "Berg", "Berg",…
# $ Article.ID                             <chr> "Bossert_et_al_2024", "Bossert_…
# $ Publication.year                       <chr> "2024", "2024", "2024", "2024",…
# $ Country                                <chr> "South Africa", "South Africa",…
# $ Latitude                               <dbl> -32.7716, -32.7716, -32.7716, -…
# $ Longitude                              <dbl> 18.14287, 18.14287, 18.14287, 1…
# $ Coastal.typology                       <chr> "Type I: Small deltas", "Type I…
# $ Marine.ecoregion                       <chr> "Temperate Southern Africa", "T…
# $ Seagrass.bioregion                     <chr> "Temperate Southern Oceans", "T…
# $ Seagrass.functionalmorphological.group <chr> "Group B: Intermediate (Halodul…
# $ Seagrass.species                       <chr> "Zostera capensis", "Zostera ca…
# $ Seagrass.genus                         <chr> "capensis", "capensis", "capens…
# $ Dry.Bulk.Density                       <dbl> 1.0301527, 1.0991792, 0.8814128…
# $ data_source                            <chr> "Bossert_et_al_2024", "Bossert_…
# $ Core.ID                                <chr> "LWR_SS1_R1", "LWR_SS1_R1", "LW…
# $ Top.of.section                         <dbl> 0, 3, 6, 10, 0, 3, 6, 10, 0, 3,…
# $ Bottom.of.section                      <dbl> 3, 6, 10, 15, 3, 6, 10, 15, 3, …
# $ Corg                                   <dbl> 0.40, 0.25, 0.97, 0.45, 0.34, 0…
# $ year                                   <dbl> 2022, 2022, 2022, 2022, 2022, 2…
# $ code_type                              <chr> "Genus species", "Genus species…
# $ Thickness.sediment.slice               <dbl> 3, 3, 4, 5, 3, 3, 4, 5, 3, 3, 4…
# $ Depth.at.center.of.slice               <dbl> 1.5, 4.5, 8.0, 12.5, 1.5, 4.5, …
# $ depth_interval                         <dbl> 3, 6, 10, 15, 3, 6, 10, 15, 3, …
# $ Corg_DBD                               <dbl> 0.004120611, 0.002747948, 0.008…
# $ Carbon_density                         <dbl> 0.012361832, 0.008243844, 0.034…
# $ Corg_DBD_interval                      <dbl> 0.012361832, 0.008243844, 0.034…
# $ cumsum_Corg_DBD                        <dbl> 0.012361832, 0.020605676, 0.054…
# $ carbon_stock_MgC_ha                    <dbl> 1.2361832, 2.0605676, 5.4804493…

# %%
# coredata_slices |>
# dplyr::filter(Core.ID %in% zaf_data_noDBD$core_id) |>
# dplyr::select(any_of(c("Article.ID", "Study.site", "Sampling.depth", "Core.ID", "depth_min_values", "depth_max_values", "stat_N_sample_Corg", "Corg.stock.15cm","Dry.Bulk.Density")))

# %%
xtabs(~ Study.site, data = coredata_slicex)
# Out:
# Study.site
#      Berg    Breede    Knysna Kobonqaba    Kromme  Mngazana  Olifants Swartkops
#       160        80        88         7        21        59        40        93

# %%
colnames(coredata_slicex)
# Out:
# Error: object 'coredata_slicex' not found
# Traceback:
#
# 1. is.data.frame(x)
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'coredata_slicex' not found", base::quote(eval(expr,
#  .     envir)))

# %%
soc_vars <- c("Corg", "Dry.Bulk.Density")
soc_depths  <- c(15, 20, 30, 50, 100)

# %%
get_slice_val <- function(data, x_val) {

      # Ensure input is a data.frame and has at least 2 columns
      if (!is.data.frame(data) || ncol(data) < 2) return(NA_real_)
      
      x_col <- names(data)[1]
      y_col <- names(data)[2]
      
      # If either column is missing, return NA
      if (is.null(x_col) || is.null(y_col)) return(NA_real_)
      
      # Defensive: ensure x_col has non-NA entries to check
      if (!x_col %in% names(data) || !y_col %in% names(data)) return(NA_real_)
      
      # Filter for exact match
      match_row <- data[data[[x_col]] == x_val, , drop = FALSE]
      
      # Return NA if no match
      if (nrow(match_row) == 0) return(NA_real_)
      
      return(match_row[[y_col]][1])
    
}

# %%
slice_check <- function(data, x_val, xreal) {
    
  if (isTRUE(x_val == xreal)) {
      return(get_slice_val(data, x_val))
  } else {
     return(NA_real_)
  }
}

# %%
na_report_list <- list()

core_varx_depthx_list <- lapply(soc_vars, function(varx) {
  
    lapply(soc_depths, function(depthx) {

    var_name <- paste0(varx, "_", depthx)
    int_var_name <- paste0("int_", varx, "_", depthx)
    N_sample_count <-  paste0("stat_N_sample_", varx)
    n_count <-  paste0("stat_n_sample_", varx)

    df <- coredata_slicex |>
          dplyr::group_by(across(all_of(grouping_cols))) |>
          dplyr::summarise(!!N_sample_count := sum(!is.na(.data[[varx]])),
                           !!n_count := n(),
                           Depth.of.core = max(Bottom.of.section),
                           !!var_name := get_slice_val(pick(depth_interval, all_of(varx)), x_val = depthx),
                           !!int_var_name := interpolate_slice(pick(depth_interval, all_of(varx)), x_val = depthx),
                           .groups = "drop") |>
          dplyr::ungroup() 

    return(df)
  })
})

# %%
core_varx_depthx_df <- Reduce(function(x, y)  merge(x, y), core_varx_depthx_list) |>  dplyr::select(-matches("\\.\\d+$"))

# %%
dim(core_varx_depthx_df)
colnames(core_varx_depthx_df)
# Out:
# [1] 131  41
#  [1] "Article.ID"
#  [2] "Publication.year"
#  [3] "Study.site"
#  [4] "Country"
#  [5] "Latitude"
#  [6] "Longitude"
#  [7] "Coastal.typology"
#  [8] "Marine.ecoregion"
#  [9] "Seagrass.bioregion"
# [10] "Seagrass.functionalmorphological.group"
# [11] "Seagrass.species"
# [12] "Seagrass.genus"
# [13] "data_source"
# [14] "Core.ID"
# [15] "year"
# [16] "code_type"
# [17] "Depth.of.core"
# [18] "stat_N_sample_Corg"
# [19] "stat_n_sample_Corg"
# [20] "Corg_15"
# [21] "int_Corg_15"
# [22] "Corg_20"
# [23] "int_Corg_20"
# [24] "Corg_30"
# [25] "int_Corg_30"
# [26] "Corg_50"
# [27] "int_Corg_50"
# [28] "Corg_100"
# [29] "int_Corg_100"
# [30] "stat_N_sample_Dry.Bulk.Density"
# [31] "stat_n_sample_Dry.Bulk.Density"
# [32] "Dry.Bulk.Density_15"
# [33] "int_Dry.Bulk.Density_15"
# [34] "Dry.Bulk.Density_20"
# [35] "int_Dry.Bulk.Density_20"
# [36] "Dry.Bulk.Density_30"
# [37] "int_Dry.Bulk.Density_30"
# [38] "Dry.Bulk.Density_50"
# [39] "int_Dry.Bulk.Density_50"
# [40] "Dry.Bulk.Density_100"
# [41] "int_Dry.Bulk.Density_100"

# %%
core_varx_depthx_df |>  
dplyr::select(c(Article.ID, Publication.year, Study.site, Depth.of.core, Core.ID, int_Dry.Bulk.Density_15), matches("Corg.stock.15")) |>
dplyr::filter(Core.ID %in% zaf_data_noDBD$core_id) |>
dplyr::filter(is.na(int_Dry.Bulk.Density_15))
# Out:
#    Article.ID              Publication.year Study.site Depth.of.core
# 1  Bekker_2015                              Knysna     5
# 2  Bekker_2015                              Knysna     5
# 3  Bekker_2015                              Knysna     5
# 4  Bekker_2015                              Knysna     5
# 5  Bezuidenhout_et_al_2011 2011             Kromme     5
# 6  Bezuidenhout_et_al_2011 2011             Kromme     5
# 7  Veldkornet_2016_PhD                      Knysna     5
# 8  Veldkornet_2016_PhD                      Knysna     5
# 9  Veldkornet_2016_PhD                      Kromme     5
# 10 Veldkornet_2016_PhD                      Kromme     5
# 11 Veldkornet_2016_PhD                      Swartkops  5
# 12 Veldkornet_2016_PhD                      Swartkops  5
# 13 Veldkornet_2016_PhD                      Swartkops  5
# 14 Veldkornet_2016_PhD                      Swartkops  5
# 15 Veldkornet_2016_PhD                      Swartkops  5
#    Core.ID
# 1  Knysna-Zostera capensis-Submerged-surface sample-1
# 2  Knysna-Zostera capensis-Submerged-surface sample-2
# 3  Knysna-Zostera capensis-Submerged-surface sample-3
# 4  Knysna-Zostera capensis-Submerged-surface sample-4
# 5  Kromme-Zostera capensis-Winter-Transect 1 Zone a-core 2
# 6  Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 2
# 7  Knysna-surface sample 42
# 8  Knysna-surface sample 43
# 9  Kromme-surface sample 15
# 10 Kromme-surface sample 16
# 11 Swartkops-surface sample 10
# 12 Swartkops-surface sample 11
# 13 Swartkops-surface sample 7
# 14 Swartkops-surface sample 8
# 15 Swartkops-surface sample 9
#    int_Dry.Bulk.Density_15
# 1  NA
# 2  NA
# 3  NA
# 4  NA
# 5  NA
# 6  NA
# 7  NA
# 8  NA
# 9  NA
# 10 NA
# 11 NA
# 12 NA
# 13 NA
# 14 NA
# 15 NA

# %%
dim(coredata_slicex)
dput(colnames(coredata_slicex))
# Out:
# [1] 548  28
# c("Study.site", "Article.ID", "Publication.year", "Country",
# "Latitude", "Longitude", "Coastal.typology", "Marine.ecoregion",
# "Seagrass.bioregion", "Seagrass.functionalmorphological.group",
# "Seagrass.species", "Seagrass.genus", "Dry.Bulk.Density", "data_source",
# "Core.ID", "Top.of.section", "Bottom.of.section", "Corg", "year",
# "code_type", "Thickness.sediment.slice", "Depth.at.center.of.slice",
# "depth_interval", "Corg_DBD", "Carbon_density", "Corg_DBD_interval",
# "cumsum_Corg_DBD", "carbon_stock_MgC_ha")

# %%
get_nearest <- function (data, depth) {
    
    Bottom.of.section <- data["Bottom.of.section"]  
    if (depth > max(Bottom.of.section)) {
        
        nearest_depth = NA
    }
    else{ 
         return(max(Bottom.of.section[Bottom.of.section <=  depth], na.rm = TRUE))
        }
}

# %%
grouping_cols
# Out:
#  [1] "Article.ID"
#  [2] "Publication.year"
#  [3] "Study.site"
#  [4] "Country"
#  [5] "Latitude"
#  [6] "Longitude"
#  [7] "Coastal.typology"
#  [8] "Marine.ecoregion"
#  [9] "Seagrass.bioregion"
# [10] "Seagrass.functionalmorphological.group"
# [11] "Seagrass.species"
# [12] "Seagrass.genus"
# [13] "data_source"
# [14] "Core.ID"
# [15] "year"
# [16] "code_type"

# %%
colnames(coredata_slices)
# Out:
#  [1] "Study.site"
#  [2] "Article.ID"
#  [3] "Publication.year"
#  [4] "Country"
#  [5] "Latitude"
#  [6] "Longitude"
#  [7] "Coastal.typology"
#  [8] "Marine.ecoregion"
#  [9] "Seagrass.bioregion"
# [10] "Seagrass.functionalmorphological.group"
# [11] "Seagrass.species"
# [12] "Seagrass.genus"
# [13] "Dry.Bulk.Density"
# [14] "data_source"
# [15] "Core.ID"
# [16] "Top.of.section"
# [17] "Bottom.of.section"
# [18] "Corg"
# [19] "year"
# [20] "code_type"
# [21] "Thickness.sediment.slice"
# [22] "Depth.at.center.of.slice"
# [23] "depth_interval"
# [24] "Corg_DBD"
# [25] "Carbon_density"
# [26] "Corg_DBD_interval"
# [27] "cumsum_Corg_DBD"
# [28] "carbon_stock_MgC_ha"

# %%
coredata_cores <- coredata_slicex |>
                  dplyr::arrange(Core.ID, Top.of.section, Bottom.of.section) |> 
                  dplyr::group_by(across(all_of(grouping_cols))) |>
                  dplyr::summarise(d15 = get_nearest(cur_data(),  15), cumsum_Corg_DBD_n15 = get_slice_val(pick(Bottom.of.section, cumsum_Corg_DBD), x_val = d15),
                                 d20 = get_nearest(cur_data(),  20), cumsum_Corg_DBD_n20 = get_slice_val(pick(Bottom.of.section, cumsum_Corg_DBD), x_val = d20),
                                 d30 = get_nearest(cur_data(),  30), cumsum_Corg_DBD_n30 = get_slice_val(pick(Bottom.of.section, cumsum_Corg_DBD), x_val = d30),
                                 d50 = get_nearest(cur_data(),  50), cumsum_Corg_DBD_n50 = get_slice_val(pick(Bottom.of.section, cumsum_Corg_DBD), x_val = d50),
                                 d100 = get_nearest(cur_data(), 100), cumsum_Corg_DBD_n100 = get_slice_val(pick(Bottom.of.section, cumsum_Corg_DBD), x_val = d100),
                                 Sampling.depth = max(Bottom.of.section),
                                 Corg.stock = get_slice_val(pick(Bottom.of.section, carbon_stock_MgC_ha), x_val = Sampling.depth),
                                 Corg.stock.15cm = get_slice_val(pick(Bottom.of.section, carbon_stock_MgC_ha), x_val = 15),
                                 Corg.stock.20cm = get_slice_val(pick(Bottom.of.section, carbon_stock_MgC_ha), x_val = 20),
                                 Corg.stock.30cm = get_slice_val(pick(Bottom.of.section, carbon_stock_MgC_ha), x_val = 30),
                                 Corg.stock.50cm = get_slice_val(pick(Bottom.of.section, carbon_stock_MgC_ha), x_val = 50),
                                 Corg.stock.100cm = get_slice_val(pick(Bottom.of.section, carbon_stock_MgC_ha), x_val = 100),
                                 depth_min_values = paste(Top.of.section, collapse = ", "),
                                depth_max_values = paste(Bottom.of.section, collapse = ", ")) |>
                 dplyr::ungroup()
# Out:
# Warning message:
# “There was 1 warning in `dplyr::summarise()`.
# ℹ In argument: `d15 = get_nearest(cur_data(), 15)`.
# ℹ In group 1: `Article.ID = "Bekker_2015"`, `Publication.year = ""`, `Study.site = "Knysna"`, `Country = "South Africa"`, `Latitude = -34.0827`, `Longitude = 23.06145`,
#   `Coastal.typology = "Type I: Small deltas"`, `Marine.ecoregion = "Temperate Southern Africa"`, `Seagrass.bioregion = "Temperate Southern Oceans"`,
#   `Seagrass.functionalmorphological.group = "Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)"`, `Seagrass.species = "Zostera capensis"`,
#   `Seagrass.genus = "capensis"`, `data_source = "Machite_et_al"`, `Core.ID = "Knysna-Zostera capensis-Submerged-surface sample-1"`, `year = 2015`, `code_type = "Genus species"`.
# Caused by warning:
# ! `cur_data()` was deprecated in dplyr 1.1.0.
# ℹ Please use `pick()` instead.”
# `summarise()` has grouped output by 'Article.ID', 'Publication.year', 'Study.site', 'Country', 'Latitude', 'Longitude', 'Coastal.typology', 'Marine.ecoregion', 'Seagrass.bioregion',
# 'Seagrass.functionalmorphological.group', 'Seagrass.species', 'Seagrass.genus', 'data_source', 'Core.ID', 'year'. You can override using the `.groups` argument.

# %%
core_varx_Corg_raw <- merge(core_varx_depthx_df, coredata_cores) |>        
                      dplyr::mutate(
                        # Depth 15
                        Corg_15 = coalesce(Corg_15, int_Corg_15),
                        Dry.Bulk.Density_15 = coalesce(Dry.Bulk.Density_15, int_Dry.Bulk.Density_15),
                        depth_diff15 = 15 - d15,
                        Carbon_density_15 = if_else(
                          depth_diff15 != 0,
                          Dry.Bulk.Density_15 * (Corg_15 / 100) * depth_diff15,
                          NA_real_
                        ),
                        Corg.stock.15cm = if_else(
                          is.na(Corg.stock.15cm),
                          (cumsum_Corg_DBD_n15 + Carbon_density_15) * 100,
                          Corg.stock.15cm
                        ),
                    
                        # Depth 20
                        Corg_20 = coalesce(Corg_20, int_Corg_20),
                        Dry.Bulk.Density_20 = coalesce(Dry.Bulk.Density_20, int_Dry.Bulk.Density_20),
                        depth_diff20 = 20 - d20,
                        Carbon_density_20 = if_else(
                          depth_diff20 != 0,
                          Dry.Bulk.Density_20 * (Corg_20 / 100) * depth_diff20,
                          NA_real_
                        ),
                        Corg.stock.20cm = if_else(
                          is.na(Corg.stock.20cm),
                          (cumsum_Corg_DBD_n20 + Carbon_density_20) * 100,
                          Corg.stock.20cm
                        ),
                
                        # Depth 30
                        Corg_30 = coalesce(Corg_30, int_Corg_30),
                        Dry.Bulk.Density_30 = coalesce(Dry.Bulk.Density_30, int_Dry.Bulk.Density_30),
                        depth_diff30 = 30 - d30,
                        Carbon_density_30 = if_else(
                          depth_diff30 != 0,
                          Dry.Bulk.Density_30 * (Corg_30 / 100) * depth_diff30,
                          NA_real_
                        ),
                        Corg.stock.30cm = if_else(
                          is.na(Corg.stock.30cm),
                          (cumsum_Corg_DBD_n30 + Carbon_density_30) * 100,
                          Corg.stock.30cm
                        ),
                    
                        # Depth 50
                        Corg_50 = coalesce(Corg_50, int_Corg_50),
                        Dry.Bulk.Density_50 = coalesce(Dry.Bulk.Density_50, int_Dry.Bulk.Density_50),
                        depth_diff50 = 50 - d50,
                        Carbon_density_50 = if_else(
                          depth_diff50 != 0,
                          Dry.Bulk.Density_50 * (Corg_50 / 100) * depth_diff50,
                          NA_real_
                        ),
                        Corg.stock.50cm = if_else(
                          is.na(Corg.stock.50cm),
                          (cumsum_Corg_DBD_n50 + Carbon_density_50) * 100,
                          Corg.stock.50cm
                        ),
                    
                        # Depth 100
                        Corg_100 = coalesce(Corg_100, int_Corg_100),
                        Dry.Bulk.Density_100 = coalesce(Dry.Bulk.Density_100, int_Dry.Bulk.Density_100),
                        depth_diff100 = 100 - d100,
                        Carbon_density_100 = if_else(
                          depth_diff100 != 0,
                          Dry.Bulk.Density_100 * (Corg_100 / 100) * depth_diff100,
                          NA_real_
                        ),
                        Corg.stock.100cm = if_else(
                          is.na(Corg.stock.100cm),
                          (cumsum_Corg_DBD_n100 + Carbon_density_100) * 100,
                          Corg.stock.100cm
                        )
                      )

# %%
colnames(core_varx_Corg_raw)
# Out:
#  [1] "Article.ID"
#  [2] "Publication.year"
#  [3] "Study.site"
#  [4] "Country"
#  [5] "Latitude"
#  [6] "Longitude"
#  [7] "Coastal.typology"
#  [8] "Marine.ecoregion"
#  [9] "Seagrass.bioregion"
# [10] "Seagrass.functionalmorphological.group"
# [11] "Seagrass.species"
# [12] "Seagrass.genus"
# [13] "data_source"
# [14] "Core.ID"
# [15] "year"
# [16] "code_type"
# [17] "Depth.of.core"
# [18] "stat_N_sample_Corg"
# [19] "stat_n_sample_Corg"
# [20] "Corg_15"
# [21] "int_Corg_15"
# [22] "Corg_20"
# [23] "int_Corg_20"
# [24] "Corg_30"
# [25] "int_Corg_30"
# [26] "Corg_50"
# [27] "int_Corg_50"
# [28] "Corg_100"
# [29] "int_Corg_100"
# [30] "stat_N_sample_Dry.Bulk.Density"
# [31] "stat_n_sample_Dry.Bulk.Density"
# [32] "Dry.Bulk.Density_15"
# [33] "int_Dry.Bulk.Density_15"
# [34] "Dry.Bulk.Density_20"
# [35] "int_Dry.Bulk.Density_20"
# [36] "Dry.Bulk.Density_30"
# [37] "int_Dry.Bulk.Density_30"
# [38] "Dry.Bulk.Density_50"
# [39] "int_Dry.Bulk.Density_50"
# [40] "Dry.Bulk.Density_100"
# [41] "int_Dry.Bulk.Density_100"
# [42] "d15"
# [43] "cumsum_Corg_DBD_n15"
# [44] "d20"
# [45] "cumsum_Corg_DBD_n20"
# [46] "d30"
# [47] "cumsum_Corg_DBD_n30"
# [48] "d50"
# [49] "cumsum_Corg_DBD_n50"
# [50] "d100"
# [51] "cumsum_Corg_DBD_n100"
# [52] "Sampling.depth"
# [53] "Corg.stock"
# [54] "Corg.stock.15cm"
# [55] "Corg.stock.20cm"
# [56] "Corg.stock.30cm"
# [57] "Corg.stock.50cm"
# [58] "Corg.stock.100cm"
# [59] "depth_min_values"
# [60] "depth_max_values"
# [61] "depth_diff15"
# [62] "Carbon_density_15"
# [63] "depth_diff20"
# [64] "Carbon_density_20"
# [65] "depth_diff30"
# [66] "Carbon_density_30"
# [67] "depth_diff50"
# [68] "Carbon_density_50"
# [69] "depth_diff100"
# [70] "Carbon_density_100"

# %%
dim(core_varx_Corg_raw)
# Out:
# [1] 131  70

# %%
missing_cols <- setdiff(Krause_stocks_cols, names(core_varx_Corg_raw))
core_varx_Corg_raw[missing_cols] <- NA
core_varx_Corg_raw <- dplyr::relocate(core_varx_Corg_raw, any_of(Krause_stocks_cols))

# %%
dim(core_varx_Corg_raw)
# Out:
# [1] 131  93

# %%
colnames(core_varx_Corg_raw)
# Out:
#  [1] "Article.ID"
#  [2] "Publication.year"
#  [3] "Study.site"
#  [4] "Country"
#  [5] "Latitude"
#  [6] "Longitude"
#  [7] "Coastal.typology"
#  [8] "Marine.ecoregion"
#  [9] "Seagrass.bioregion"
# [10] "Seagrass.functionalmorphological.group"
# [11] "Seagrass.species"
# [12] "Seagrass.genus"
# [13] "Additional.identification"
# [14] "Above.ground.biomass"
# [15] "Below.ground.biomass"
# [16] "Total.biomass"
# [17] "Sampling.depth"
# [18] "Ctot.stock"
# [19] "Ctot.content"
# [20] "Corg.stock"
# [21] "Corg.content"
# [22] "Cinorg.stock"
# [23] "Cinorg.content"
# [24] "Ctot.stock.15cm"
# [25] "Corg.stock.15cm"
# [26] "Cinorg.stock.15cm"
# [27] "Ctot.stock.30cm"
# [28] "Corg.stock.30cm"
# [29] "Cinorg.stock.30cm"
# [30] "Ctot.stock.50cm"
# [31] "Corg.stock.50cm"
# [32] "Cinorg.stock.50cm"
# [33] "Ctot.stock.100cm"
# [34] "Corg.stock.100cm"
# [35] "Cinorg.stock.100cm"
# [36] "OM.content"
# [37] "Porosity"
# [38] "Dry.Bulk.Density"
# [39] "Grain.size"
# [40] "Fraction.mud"
# [41] "Notes"
# [42] "data_source"
# [43] "Core.ID"
# [44] "year"
# [45] "code_type"
# [46] "Depth.of.core"
# [47] "stat_N_sample_Corg"
# [48] "stat_n_sample_Corg"
# [49] "Corg_15"
# [50] "int_Corg_15"
# [51] "Corg_20"
# [52] "int_Corg_20"
# [53] "Corg_30"
# [54] "int_Corg_30"
# [55] "Corg_50"
# [56] "int_Corg_50"
# [57] "Corg_100"
# [58] "int_Corg_100"
# [59] "stat_N_sample_Dry.Bulk.Density"
# [60] "stat_n_sample_Dry.Bulk.Density"
# [61] "Dry.Bulk.Density_15"
# [62] "int_Dry.Bulk.Density_15"
# [63] "Dry.Bulk.Density_20"
# [64] "int_Dry.Bulk.Density_20"
# [65] "Dry.Bulk.Density_30"
# [66] "int_Dry.Bulk.Density_30"
# [67] "Dry.Bulk.Density_50"
# [68] "int_Dry.Bulk.Density_50"
# [69] "Dry.Bulk.Density_100"
# [70] "int_Dry.Bulk.Density_100"
# [71] "d15"
# [72] "cumsum_Corg_DBD_n15"
# [73] "d20"
# [74] "cumsum_Corg_DBD_n20"
# [75] "d30"
# [76] "cumsum_Corg_DBD_n30"
# [77] "d50"
# [78] "cumsum_Corg_DBD_n50"
# [79] "d100"
# [80] "cumsum_Corg_DBD_n100"
# [81] "Corg.stock.20cm"
# [82] "depth_min_values"
# [83] "depth_max_values"
# [84] "depth_diff15"
# [85] "Carbon_density_15"
# [86] "depth_diff20"
# [87] "Carbon_density_20"
# [88] "depth_diff30"
# [89] "Carbon_density_30"
# [90] "depth_diff50"
# [91] "Carbon_density_50"
# [92] "depth_diff100"
# [93] "Carbon_density_100"

# %%
core_varx_Corg_final <- dplyr::filter(core_varx_Corg_raw, Sampling.depth > 5) |>
                        dplyr::relocate(all_of(Krause_stocks_cols))

# %%
core_varx_Corg_final |>  
dplyr::select(c(Article.ID, Study.site, Sampling.depth, Core.ID, depth_min_values, depth_max_values, stat_N_sample_Corg), matches("Corg.stock.15cm")) |>
dplyr::filter(Core.ID %in% zaf_data_noDBD$core_id)
# Out:
#    Article.ID              Study.site Sampling.depth
# 1  Bezuidenhout_et_al_2011 Kromme     120
# 2  Bezuidenhout_et_al_2011 Kromme     120
# 3  Bezuidenhout_et_al_2011 Kromme      15
# 4  Bezuidenhout_et_al_2011 Kromme     120
# 5  Bezuidenhout_et_al_2011 Kromme     120
# 6  Bezuidenhout_et_al_2011 Kromme     120
# 7  Brown_and_Rajkaran_2020 Kobonqaba   21
# 8  Els_2017                Knysna      56
# 9  Els_2017                Knysna      56
# 10 Els_2017                Knysna     110
# 11 Els_2017                Knysna     110
# 12 Els_2019                Swartkops  100
# 13 Els_2019                Swartkops  100
# 14 Els_2019                Swartkops  100
# 15 Els_2019                Swartkops  100
# 16 Els_2019                Swartkops  100
# 17 Els_2019                Swartkops  100
# 18 Els_2019                Swartkops  100
# 19 Els_2019                Swartkops  100
# 20 Els_2019                Swartkops  100
# 21 Els_2019                Swartkops  100
# 22 Els_2019                Swartkops  100
# 23 Els_2019                Swartkops  100
# 24 Rajkaran_and_Adams_2011 Mngazana    39
#    Core.ID
# 1  Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 1
# 2  Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 1
# 3  Kromme-Zostera capensis-Winter-Transect 1 Zone a-core 1
# 4  Kromme-Zostera capensis-Summer-Transect 1 Zone a-core 2
# 5  Kromme-Zostera capensis-Summer-Transect 2 Zone a-core 2
# 6  Kromme-Zostera capensis-Winter-Transect 2 Zone a-core 1
# 7  Kobonqaba-Zostera capensis-core 1
# 8  Knysna-Ashmead-core-1
# 9  Knysna-Lower-core-1
# 10 Knysna-Middle-core-1
# 11 Knysna-Upper-core-1
# 12 Swartkops-6-Winter-core-2
# 13 Swartkops-1-Summer-core-3
# 14 Swartkops-1-Winter-core-3
# 15 Swartkops-2-Summer-core-3
# 16 Swartkops-2-Winter-core-3
# 17 Swartkops-3-Summer-core-3
# 18 Swartkops-3-Winter-core-3
# 19 Swartkops-4-Summer-core-3
# 20 Swartkops-4-Winter-core-3
# 21 Swartkops-5-Summer-core-3
# 22 Swartkops-5-Winter-core-3
# 23 Swartkops-6-Summer-core-1
# 24 Mngazana-core-1
#    depth_min_values
# 1  0, 5, 100
# 2  0, 5, 100
# 3  0, 5
# 4  0, 5, 100
# 5  0, 5, 100
# 6  0, 5, 100
# 7  0, 3, 6, 9, 12, 15, 18
# 8  0, 10, 21, 25, 35, 42, 50
# 9  0, 10, 21, 25, 35, 42, 50
# 10 0, 10, 21, 25, 35, 42, 49, 50, 56, 63, 70, 80, 90, 100
# 11 0, 10, 21, 25, 35, 42, 49, 50, 56, 63, 70, 80, 90, 100
# 12 0, 10, 25, 50
# 13 0, 10, 25, 50
# 14 0, 10, 25, 50
# 15 0, 10, 25, 50
# 16 0, 10, 25, 50
# 17 0, 10, 25, 50
# 18 0, 10, 25, 50
# 19 0, 10, 25, 50
# 20 0, 10, 25, 50
# 21 0, 10, 25, 50
# 22 0, 10, 25, 50
# 23 0, 10, 25, 50
# 24 0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36
#    depth_max_values                                         stat_N_sample_Corg
# 1  5, 15, 120                                                3
# 2  5, 15, 120                                                3
# 3  5, 15                                                     2
# 4  5, 15, 120                                                3
# 5  5, 15, 120                                                3
# 6  5, 15, 120                                                3
# 7  3, 6, 9, 12, 15, 18, 21                                   7
# 8  10, 21, 25, 35, 42, 49, 56                                7
# 9  10, 21, 25, 35, 42, 49, 56                                7
# 10 10, 21, 25, 35, 42, 49, 50, 56, 63, 70, 80, 90, 100, 110 14
# 11 10, 21, 25, 35, 42, 49, 50, 56, 63, 70, 80, 90, 100, 110 14
# 12 10, 25, 50, 100                                           4
# 13 10, 25, 50, 100                                           4
# 14 10, 25, 50, 100                                           4
# 15 10, 25, 50, 100                                           4
# 16 10, 25, 50, 100                                           4
# 17 10, 25, 50, 100                                           4
# 18 10, 25, 50, 100                                           4
# 19 10, 25, 50, 100                                           4
# 20 10, 25, 50, 100                                           4
# 21 10, 25, 50, 100                                           4
# 22 10, 25, 50, 100                                           4
# 23 10, 25, 50, 100                                           4
# 24 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39          13
#    Corg.stock.15cm
# 1   11.22102
# 2   19.00065
# 3   28.88599
# 4  103.97883
# 5  133.09776
# 6   21.06116
# 7  114.98380
# 8   55.22132
# 9   52.39744
# 10  59.82124
# 11  54.39292
# 12  57.59701
# 13 125.42953
# 14  37.82376
# 15 106.05489
# 16  86.68696
# 17  83.66198
# 18  87.37659
# 19 109.75815
# 20  80.65953
# 21  53.67795
# 22  54.47253
# 23  54.51696
# 24 164.25968

# %%
core_varx_Corg_final |>  
dplyr::select(Article.ID, Study.site, Sampling.depth, Core.ID,	depth_min_values,	depth_max_values,	stat_N_sample_Corg,	Corg.stock.15cm) |>
dplyr::filter(Study.site == "Breede")
# Out:
#    Article.ID         Study.site Sampling.depth Core.ID    depth_min_values
# 1  Bossert_et_al_2024 Breede     15             UPR_SS1_R1 0, 3, 6, 10
# 2  Bossert_et_al_2024 Breede     15             UPR_SS1_R2 0, 3, 6, 10
# 3  Bossert_et_al_2024 Breede     15             UPR_SS1_R3 0, 3, 6, 10
# 4  Bossert_et_al_2024 Breede     15             UPR_SS1_R4 0, 3, 6, 10
# 5  Bossert_et_al_2024 Breede     15             UPR_SS1_R5 0, 3, 6, 10
# 6  Bossert_et_al_2024 Breede     15             UPR_SS2_R1 0, 3, 6, 10
# 7  Bossert_et_al_2024 Breede     15             UPR_SS2_R2 0, 3, 6, 10
# 8  Bossert_et_al_2024 Breede     15             UPR_SS2_R3 0, 3, 6, 10
# 9  Bossert_et_al_2024 Breede     15             UPR_SS2_R4 0, 3, 6, 10
# 10 Bossert_et_al_2024 Breede     15             UPR_SS2_R5 0, 3, 6, 10
# 11 Bossert_et_al_2024 Breede     15             UPR_SS3_R1 0, 3, 6, 10
# 12 Bossert_et_al_2024 Breede     15             UPR_SS3_R2 0, 3, 6, 10
# 13 Bossert_et_al_2024 Breede     15             UPR_SS3_R3 0, 3, 6, 10
# 14 Bossert_et_al_2024 Breede     15             UPR_SS3_R4 0, 3, 6, 10
# 15 Bossert_et_al_2024 Breede     15             UPR_SS3_R5 0, 3, 6, 10
# 16 Ndhlovu_et_al_2024 Breede     50             Breede2_C1 0, 5, 10, 20, 30
# 17 Ndhlovu_et_al_2024 Breede     50             Breede2_C2 0, 5, 10, 20, 30
# 18 Ndhlovu_et_al_2024 Breede     50             Breede2_C3 0, 5, 10, 20, 30
# 19 Ndhlovu_et_al_2024 Breede     50             Breede2_C4 0, 5, 10, 20, 30
#    depth_max_values  stat_N_sample_Corg Corg.stock.15cm
# 1  3, 6, 10, 15      4                  11.572925
# 2  3, 6, 10, 15      4                  13.665641
# 3  3, 6, 10, 15      4                  12.313227
# 4  3, 6, 10, 15      4                   9.946406
# 5  3, 6, 10, 15      4                  10.021230
# 6  3, 6, 10, 15      4                  12.774940
# 7  3, 6, 10, 15      4                  10.963883
# 8  3, 6, 10, 15      4                  12.162292
# 9  3, 6, 10, 15      4                  15.270893
# 10 3, 6, 10, 15      4                   9.954622
# 11 3, 6, 10, 15      4                   8.206169
# 12 3, 6, 10, 15      4                   9.351095
# 13 3, 6, 10, 15      4                  11.539196
# 14 3, 6, 10, 15      4                   9.170738
# 15 3, 6, 10, 15      4                  43.096338
# 16 5, 10, 20, 30, 50 5                   1.455444
# 17 5, 10, 20, 30, 50 5                   4.785426
# 18 5, 10, 20, 30, 50 5                   2.925773
# 19 5, 10, 20, 30, 50 5                   6.691683

# %%
core_varx_Corg_final
# Out:
#     Article.ID              Publication.year Study.site Country      Latitude
# 1   Bezuidenhout_et_al_2011 2011             Kromme     South Africa -34.14297
# 2   Bezuidenhout_et_al_2011 2011             Kromme     South Africa -34.14297
# 3   Bezuidenhout_et_al_2011 2011             Kromme     South Africa -34.14297
# 4   Bezuidenhout_et_al_2011 2011             Kromme     South Africa -34.14297
# 5   Bezuidenhout_et_al_2011 2011             Kromme     South Africa -34.14297
# 6   Bezuidenhout_et_al_2011 2011             Kromme     South Africa -34.14297
# 7   Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 8   Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 9   Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 10  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 11  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 12  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 13  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 14  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 15  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 16  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 17  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 18  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 19  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 20  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 21  Bossert_et_al_2024      2024             Berg       South Africa -32.77160
# 22  Bossert_et_al_2024      2024             Berg       South Africa -32.81825
# 23  Bossert_et_al_2024      2024             Berg       South Africa -32.81825
# 24  Bossert_et_al_2024      2024             Berg       South Africa -32.81825
# 25  Bossert_et_al_2024      2024             Berg       South Africa -32.81825
# 26  Bossert_et_al_2024      2024             Berg       South Africa -32.81825
# 27  Bossert_et_al_2024      2024             Berg       South Africa -32.81825
# 28  Bossert_et_al_2024      2024             Berg       South Africa -32.81825
# 29  Bossert_et_al_2024      2024             Berg       South Africa -32.81825
# 30  Bossert_et_al_2024      2024             Berg       South Africa -32.81825
# ⋮   ⋮                       ⋮                ⋮          ⋮            ⋮
# 87  Ndhlovu_et_al_2024      2024             Knysna     South Africa  23.05105
# 88  Ndhlovu_et_al_2024      2024             Knysna     South Africa  23.05105
# 89  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.41853
# 90  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.41853
# 91  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.41853
# 92  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.41853
# 93  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.41853
# 94  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.42223
# 95  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.42223
# 96  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.42223
# 97  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.42223
# 98  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.42223
# 99  Ndhlovu_et_al_2024      2024             Mngazana   South Africa  29.42223
# 100 Ndhlovu_et_al_2024      2024             Olifants   South Africa  18.18641
# 101 Ndhlovu_et_al_2024      2024             Olifants   South Africa  18.18641
# 102 Ndhlovu_et_al_2024      2024             Olifants   South Africa  18.18641
# 103 Ndhlovu_et_al_2024      2024             Olifants   South Africa  18.18641
# 104 Ndhlovu_et_al_2024      2024             Olifants   South Africa  18.18882
# 105 Ndhlovu_et_al_2024      2024             Olifants   South Africa  18.18882
# 106 Ndhlovu_et_al_2024      2024             Olifants   South Africa  18.18882
# 107 Ndhlovu_et_al_2024      2024             Olifants   South Africa  18.18882
# 108 Ndhlovu_et_al_2024      2024             Swartkops  South Africa  25.59069
# 109 Ndhlovu_et_al_2024      2024             Swartkops  South Africa  25.59069
# 110 Ndhlovu_et_al_2024      2024             Swartkops  South Africa  25.59069
# 111 Ndhlovu_et_al_2024      2024             Swartkops  South Africa  25.59069
# 112 Ndhlovu_et_al_2024      2024             Swartkops  South Africa  25.62139
# 113 Ndhlovu_et_al_2024      2024             Swartkops  South Africa  25.62139
# 114 Ndhlovu_et_al_2024      2024             Swartkops  South Africa  25.62139
# 115 Ndhlovu_et_al_2024      2024             Swartkops  South Africa  25.62139
# 116 Rajkaran_and_Adams_2011 2011             Mngazana   South Africa -31.69218
#     Longitude Coastal.typology     Marine.ecoregion
# 1   24.50000  Type I: Small deltas Temperate Southern Africa
# 2   24.50000  Type I: Small deltas Temperate Southern Africa
# 3   24.50000  Type I: Small deltas Temperate Southern Africa
# 4   24.84273  Type I: Small deltas Temperate Southern Africa
# 5   24.84273  Type I: Small deltas Temperate Southern Africa
# 6   24.84273  Type I: Small deltas Temperate Southern Africa
# 7   18.14287  Type I: Small deltas Temperate Southern Africa
# 8   18.14287  Type I: Small deltas Temperate Southern Africa
# 9   18.14287  Type I: Small deltas Temperate Southern Africa
# 10  18.14287  Type I: Small deltas Temperate Southern Africa
# 11  18.14287  Type I: Small deltas Temperate Southern Africa
# 12  18.14287  Type I: Small deltas Temperate Southern Africa
# 13  18.14287  Type I: Small deltas Temperate Southern Africa
# 14  18.14287  Type I: Small deltas Temperate Southern Africa
# 15  18.14287  Type I: Small deltas Temperate Southern Africa
# 16  18.14287  Type I: Small deltas Temperate Southern Africa
# 17  18.14287  Type I: Small deltas Temperate Southern Africa
# 18  18.14287  Type I: Small deltas Temperate Southern Africa
# 19  18.14287  Type I: Small deltas Temperate Southern Africa
# 20  18.14287  Type I: Small deltas Temperate Southern Africa
# 21  18.14287  Type I: Small deltas Temperate Southern Africa
# 22  18.19599  Type I: Small deltas Temperate Southern Africa
# 23  18.19599  Type I: Small deltas Temperate Southern Africa
# 24  18.19599  Type I: Small deltas Temperate Southern Africa
# 25  18.19599  Type I: Small deltas Temperate Southern Africa
# 26  18.19599  Type I: Small deltas Temperate Southern Africa
# 27  18.19599  Type I: Small deltas Temperate Southern Africa
# 28  18.19599  Type I: Small deltas Temperate Southern Africa
# 29  18.19599  Type I: Small deltas Temperate Southern Africa
# 30  18.19599  Type I: Small deltas Temperate Southern Africa
# ⋮   ⋮         ⋮                    ⋮
# 87  -34.05871 Type I: Small deltas Temperate Southern Africa
# 88  -34.05871 Type I: Small deltas Temperate Southern Africa
# 89  -31.68501 Type I: Small deltas Temperate Southern Africa
# 90  -31.68501 Type I: Small deltas Temperate Southern Africa
# 91  -31.68501 Type I: Small deltas Temperate Southern Africa
# 92  -31.68501 Type I: Small deltas Temperate Southern Africa
# 93  -31.68501 Type I: Small deltas Temperate Southern Africa
# 94  -31.69004 Type I: Small deltas Temperate Southern Africa
# 95  -31.69004 Type I: Small deltas Temperate Southern Africa
# 96  -31.69004 Type I: Small deltas Temperate Southern Africa
# 97  -31.69004 Type I: Small deltas Temperate Southern Africa
# 98  -31.69004 Type I: Small deltas Temperate Southern Africa
# 99  -31.69004 Type I: Small deltas Temperate Southern Africa
# 100 -31.66462 Type I: Small deltas Temperate Southern Africa
# 101 -31.66462 Type I: Small deltas Temperate Southern Africa
# 102 -31.66462 Type I: Small deltas Temperate Southern Africa
# 103 -31.66462 Type I: Small deltas Temperate Southern Africa
# 104 -31.69302 Type I: Small deltas Temperate Southern Africa
# 105 -31.69302 Type I: Small deltas Temperate Southern Africa
# 106 -31.69302 Type I: Small deltas Temperate Southern Africa
# 107 -31.69302 Type I: Small deltas Temperate Southern Africa
# 108 -33.83784 Type I: Small deltas Temperate Southern Africa
# 109 -33.83784 Type I: Small deltas Temperate Southern Africa
# 110 -33.83784 Type I: Small deltas Temperate Southern Africa
# 111 -33.83784 Type I: Small deltas Temperate Southern Africa
# 112 -33.86114 Type I: Small deltas Temperate Southern Africa
# 113 -33.86114 Type I: Small deltas Temperate Southern Africa
# 114 -33.86114 Type I: Small deltas Temperate Southern Africa
# 115 -33.86114 Type I: Small deltas Temperate Southern Africa
# 116  29.42286 Type I: Small deltas Temperate Southern Africa
#     Seagrass.bioregion
# 1   Temperate Southern Oceans
# 2   Temperate Southern Oceans
# 3   Temperate Southern Oceans
# 4   Temperate Southern Oceans
# 5   Temperate Southern Oceans
# 6   Temperate Southern Oceans
# 7   Temperate Southern Oceans
# 8   Temperate Southern Oceans
# 9   Temperate Southern Oceans
# 10  Temperate Southern Oceans
# 11  Temperate Southern Oceans
# 12  Temperate Southern Oceans
# 13  Temperate Southern Oceans
# 14  Temperate Southern Oceans
# 15  Temperate Southern Oceans
# 16  Temperate Southern Oceans
# 17  Temperate Southern Oceans
# 18  Temperate Southern Oceans
# 19  Temperate Southern Oceans
# 20  Temperate Southern Oceans
# 21  Temperate Southern Oceans
# 22  Temperate Southern Oceans
# 23  Temperate Southern Oceans
# 24  Temperate Southern Oceans
# 25  Temperate Southern Oceans
# 26  Temperate Southern Oceans
# 27  Temperate Southern Oceans
# 28  Temperate Southern Oceans
# 29  Temperate Southern Oceans
# 30  Temperate Southern Oceans
# ⋮   ⋮
# 87  Temperate Southern Oceans
# 88  Temperate Southern Oceans
# 89  Temperate Southern Oceans
# 90  Temperate Southern Oceans
# 91  Temperate Southern Oceans
# 92  Temperate Southern Oceans
# 93  Temperate Southern Oceans
# 94  Temperate Southern Oceans
# 95  Temperate Southern Oceans
# 96  Temperate Southern Oceans
# 97  Temperate Southern Oceans
# 98  Temperate Southern Oceans
# 99  Temperate Southern Oceans
# 100 Temperate Southern Oceans
# 101 Temperate Southern Oceans
# 102 Temperate Southern Oceans
# 103 Temperate Southern Oceans
# 104 Temperate Southern Oceans
# 105 Temperate Southern Oceans
# 106 Temperate Southern Oceans
# 107 Temperate Southern Oceans
# 108 Temperate Southern Oceans
# 109 Temperate Southern Oceans
# 110 Temperate Southern Oceans
# 111 Temperate Southern Oceans
# 112 Temperate Southern Oceans
# 113 Temperate Southern Oceans
# 114 Temperate Southern Oceans
# 115 Temperate Southern Oceans
# 116 Temperate Southern Oceans
#     Seagrass.functionalmorphological.group
# 1   Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 2   Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 3   Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 4   Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 5   Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 6   Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 7   Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 8   Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 9   Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 10  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 11  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 12  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 13  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 14  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 15  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 16  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 17  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 18  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 19  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 20  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 21  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 22  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 23  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 24  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 25  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 26  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 27  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 28  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 29  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 30  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# ⋮   ⋮
# 87  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 88  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 89  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 90  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 91  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 92  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 93  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 94  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 95  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 96  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 97  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 98  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 99  Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 100 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 101 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 102 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 103 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 104 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 105 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 106 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 107 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 108 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 109 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 110 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 111 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 112 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 113 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 114 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 115 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
# 116 Group B: Intermediate (Halodule, Zostera, Heterozostera, Syringodium, Cymodocea sp.)
#     ⋯ depth_diff15 Carbon_density_15 depth_diff20 Carbon_density_20
# 1   ⋯ 0            NA                 5           0.1158425
# 2   ⋯ 0            NA                 5           0.1830335
# 3   ⋯ 0            NA                NA                  NA
# 4   ⋯ 0            NA                 5           0.7953324
# 5   ⋯ 0            NA                 5           1.0757670
# 6   ⋯ 0            NA                 5           0.1996648
# 7   ⋯ 0            NA                NA                  NA
# 8   ⋯ 0            NA                NA                  NA
# 9   ⋯ 0            NA                NA                  NA
# 10  ⋯ 0            NA                NA                  NA
# 11  ⋯ 0            NA                NA                  NA
# 12  ⋯ 0            NA                NA                  NA
# 13  ⋯ 0            NA                NA                  NA
# 14  ⋯ 0            NA                NA                  NA
# 15  ⋯ 0            NA                NA                  NA
# 16  ⋯ 0            NA                NA                  NA
# 17  ⋯ 0            NA                NA                  NA
# 18  ⋯ 0            NA                NA                  NA
# 19  ⋯ 0            NA                NA                  NA
# 20  ⋯ 0            NA                NA                  NA
# 21  ⋯ 0            NA                NA                  NA
# 22  ⋯ 0            NA                NA                  NA
# 23  ⋯ 0            NA                NA                  NA
# 24  ⋯ 0            NA                NA                  NA
# 25  ⋯ 0            NA                NA                  NA
# 26  ⋯ 0            NA                NA                  NA
# 27  ⋯ 0            NA                NA                  NA
# 28  ⋯ 0            NA                NA                  NA
# 29  ⋯ 0            NA                NA                  NA
# 30  ⋯ 0            NA                NA                  NA
# ⋮   ⋱ ⋮            ⋮                 ⋮            ⋮
# 87  ⋯ 5            0.032443872       0                   NA
# 88  ⋯ 5            0.011175643       0                   NA
# 89  ⋯ 5            0.053595791       0                   NA
# 90  ⋯ 5            0.055898621       0                   NA
# 91  ⋯ 5            0.046492086       0                   NA
# 92  ⋯ 5            0.050877192       0                   NA
# 93  ⋯ 5            0.034254739       0                   NA
# 94  ⋯ 5            0.098389063       0                   NA
# 95  ⋯ 5            0.074064292       0                   NA
# 96  ⋯ 5            0.118340369       0                   NA
# 97  ⋯ 5            0.095124607       0                   NA
# 98  ⋯ 5            0.083772817       0                   NA
# 99  ⋯ 5            0.035828172       0                   NA
# 100 ⋯ 5            0.015321046       0                   NA
# 101 ⋯ 5            0.013590665       0                   NA
# 102 ⋯ 5            0.009110680       0                   NA
# 103 ⋯ 5            0.005723625       0                   NA
# 104 ⋯ 5            0.020705086       0                   NA
# 105 ⋯ 5            0.015520639       0                   NA
# 106 ⋯ 5            0.028356588       0                   NA
# 107 ⋯ 5            0.019924585       0                   NA
# 108 ⋯ 5            0.007641771       0                   NA
# 109 ⋯ 5            0.007983094       0                   NA
# 110 ⋯ 5            0.030133250       0                   NA
# 111 ⋯ 5            0.008703432       0                   NA
# 112 ⋯ 5            0.146572428       0                   NA
# 113 ⋯ 5            0.192907013       0                   NA
# 114 ⋯ 5            0.244489376       0                   NA
# 115 ⋯ 5            0.195837422       0                   NA
# 116 ⋯ 0                     NA       2            0.5644386
#     depth_diff30 Carbon_density_30 depth_diff50 Carbon_density_50 depth_diff100
# 1   15           0.3382384         35           0.726104          85
# 2   15           0.5332466         35           1.138184          85
# 3   NA                  NA         NA                 NA          NA
# 4   15           2.4104873         35           5.665676          85
# 5   15           3.2608433         35           7.666612          85
# 6   15           0.5768496         35           1.204209          85
# 7   NA                  NA         NA                 NA          NA
# 8   NA                  NA         NA                 NA          NA
# 9   NA                  NA         NA                 NA          NA
# 10  NA                  NA         NA                 NA          NA
# 11  NA                  NA         NA                 NA          NA
# 12  NA                  NA         NA                 NA          NA
# 13  NA                  NA         NA                 NA          NA
# 14  NA                  NA         NA                 NA          NA
# 15  NA                  NA         NA                 NA          NA
# 16  NA                  NA         NA                 NA          NA
# 17  NA                  NA         NA                 NA          NA
# 18  NA                  NA         NA                 NA          NA
# 19  NA                  NA         NA                 NA          NA
# 20  NA                  NA         NA                 NA          NA
# 21  NA                  NA         NA                 NA          NA
# 22  NA                  NA         NA                 NA          NA
# 23  NA                  NA         NA                 NA          NA
# 24  NA                  NA         NA                 NA          NA
# 25  NA                  NA         NA                 NA          NA
# 26  NA                  NA         NA                 NA          NA
# 27  NA                  NA         NA                 NA          NA
# 28  NA                  NA         NA                 NA          NA
# 29  NA                  NA         NA                 NA          NA
# 30  NA                  NA         NA                 NA          NA
# ⋮   ⋮            ⋮                 ⋮            ⋮                 ⋮
# 87   0           NA                 0           NA                NA
# 88   0           NA                 0           NA                NA
# 89   0           NA                NA           NA                NA
# 90   0           NA                NA           NA                NA
# 91   0           NA                NA           NA                NA
# 92  NA           NA                NA           NA                NA
# 93   0           NA                 0           NA                NA
# 94   0           NA                NA           NA                NA
# 95   0           NA                NA           NA                NA
# 96   0           NA                NA           NA                NA
# 97   0           NA                 0           NA                NA
# 98   0           NA                NA           NA                NA
# 99   0           NA                 0           NA                NA
# 100  0           NA                 0           NA                NA
# 101  0           NA                 0           NA                NA
# 102  0           NA                 0           NA                NA
# 103  0           NA                 0           NA                NA
# 104  0           NA                 0           NA                NA
# 105  0           NA                 0           NA                NA
# 106  0           NA                 0           NA                NA
# 107  0           NA                 0           NA                NA
# 108  0           NA                 0           NA                NA
# 109  0           NA                 0           NA                NA
# 110  0           NA                 0           NA                NA
# 111  0           NA                 0           NA                NA
# 112  0           NA                 0           NA                NA
# 113  0           NA                 0           NA                NA
# 114  0           NA                 0           NA                NA
# 115  0           NA                 0           NA                NA
# 116  0           NA                NA           NA                NA
#     Carbon_density_100
# 1    1.100092
# 2    1.665862
# 3          NA
# 4   12.974359
# 5   17.574751
# 6    1.519304
# 7          NA
# 8          NA
# 9          NA
# 10         NA
# 11         NA
# 12         NA
# 13         NA
# 14         NA
# 15         NA
# 16         NA
# 17         NA
# 18         NA
# 19         NA
# 20         NA
# 21         NA
# 22         NA
# 23         NA
# 24         NA
# 25         NA
# 26         NA
# 27         NA
# 28         NA
# 29         NA
# 30         NA
# ⋮   ⋮
# 87  NA
# 88  NA
# 89  NA
# 90  NA
# 91  NA
# 92  NA
# 93  NA
# 94  NA
# 95  NA
# 96  NA
# 97  NA
# 98  NA
# 99  NA
# 100 NA
# 101 NA
# 102 NA
# 103 NA
# 104 NA
# 105 NA
# 106 NA
# 107 NA
# 108 NA
# 109 NA
# 110 NA
# 111 NA
# 112 NA
# 113 NA
# 114 NA
# 115 NA
# 116 NA
